# %% [markdown]
# <a href="https://colab.research.google.com/github/shyakaster/chinook-repo/blob/main/chinook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3477a1c0-5ca0-4631-b554-8da763f13e8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3477a1c0-5ca0-4631-b554-8da763f13e8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd;
clean_invoice=pd.read_csv('/content/drive/MyDrive/sample_data/clean-invoice.csv',index_col='invoice_id');
clean_invoice.head()
# Out:
#             customer_id         invoice_date          billing_address  \
# invoice_id
# 1                     2  2021-01-01 00:00:00  Theodor-Heuss-Straße 34
# 2                     4  2021-01-02 00:00:00         Ullevålsveien 14
# 3                     8  2021-01-03 00:00:00          Grétrystraat 63
# 4                    14  2021-01-06 00:00:00           8210 111 ST NW
# 5                    23  2021-01-11 00:00:00          69 Salem Street
#
#            billing_city billing_state billing_country billing_postal_code  \
# invoice_id
# 1             Stuttgart       Unknown         Germany               70174
# 2                  Oslo       Unknown          Norway                0171
# 3              Brussels       Unknown         Belgium                1000
# 4              Edmonton            AB          Canada             T6G 2C7
# 5                Boston            MA             USA                2113
#
#             total
# invoice_id
# 1            1.98
# 2            3.96
# ...

# %%
# clean_invoice['billing_state'].fillna('Unknown', inplace=True)
# clean_invoice['billing_postal_code'].fillna('Unknown', inplace=True)
clean_invoice.head()
# Out:
#             customer_id         invoice_date          billing_address  \
# invoice_id
# 1                     2  2021-01-01 00:00:00  Theodor-Heuss-Straße 34
# 2                     4  2021-01-02 00:00:00         Ullevålsveien 14
# 3                     8  2021-01-03 00:00:00          Grétrystraat 63
# 4                    14  2021-01-06 00:00:00           8210 111 ST NW
# 5                    23  2021-01-11 00:00:00          69 Salem Street
#
#            billing_city billing_state billing_country billing_postal_code  \
# invoice_id
# 1             Stuttgart       Unknown         Germany               70174
# 2                  Oslo       Unknown          Norway                0171
# 3              Brussels       Unknown         Belgium                1000
# 4              Edmonton            AB          Canada             T6G 2C7
# 5                Boston            MA             USA                2113
#
#             total
# invoice_id
# 1            1.98
# 2            3.96
# ...

# %%
clean_invoice.isna().sum()
# Out:
# customer_id            0
# invoice_date           0
# billing_address        0
# billing_city           0
# billing_state          0
# billing_country        0
# billing_postal_code    0
# total                  0
# dtype: int64

# %%
clean_invoice.to_csv('/content/drive/MyDrive/sample_data/clean-invoice.csv')

# %%
clean_customer=pd.read_csv('/content/drive/MyDrive/sample_data/clean-customer.csv',index_col='customer_id');
clean_customer.head()
# Out:
#             first_name    last_name  \
# customer_id
# 1                 Luís    Gonçalves
# 2               Leonie       Köhler
# 3             François     Tremblay
# 4                Bjørn       Hansen
# 5            František  Wichterlová
#
#                                                       company  \
# customer_id
# 1            Embraer - Empresa Brasileira de Aeronáutica S.A.
# 2                                                     Unknown
# 3                                                     Unknown
# 4                                                     Unknown
# 5                                            JetBrains s.r.o.
#
#                                      address                 city    state  \
# customer_id
# 1            Av. Brigadeiro Faria Lima, 2170  São José dos Campos       SP
# 2                    Theodor-Heuss-Straße 34            Stuttgart  Unknown
# 3                          1498 rue Bélanger             Montréal       QC
# ...

# %%
# cleaning the customer dataset
# clean_customer['company'].fillna('Unknown', inplace=True)
# clean_customer['postal_code'].fillna('Unknown', inplace=True)
# clean_customer['phone'].fillna('Unknown', inplace=True)
# clean_customer['state'].fillna('Unknown', inplace=True)
# clean_customer['fax'].fillna('Unknown', inplace=True)

clean_customer.head()
# Out:
#             first_name    last_name  \
# customer_id
# 1                 Luís    Gonçalves
# 2               Leonie       Köhler
# 3             François     Tremblay
# 4                Bjørn       Hansen
# 5            František  Wichterlová
#
#                                                       company  \
# customer_id
# 1            Embraer - Empresa Brasileira de Aeronáutica S.A.
# 2                                                     Unknown
# 3                                                     Unknown
# 4                                                     Unknown
# 5                                            JetBrains s.r.o.
#
#                                      address                 city    state  \
# customer_id
# 1            Av. Brigadeiro Faria Lima, 2170  São José dos Campos       SP
# 2                    Theodor-Heuss-Straße 34            Stuttgart  Unknown
# 3                          1498 rue Bélanger             Montréal       QC
# ...

# %%
clean_customer.isna().sum()
# Out:
# first_name        0
# last_name         0
# company           0
# address           0
# city              0
# state             0
# country           0
# postal_code       0
# phone             0
# fax               0
# email             0
# support_rep_id    0
# dtype: int64

# %%
# clean_invoice.to_csv('sample_data/clean-invoice.csv')
clean_customer.to_csv('/content/drive/MyDrive/sample_data/clean-customer.csv')

# %%
# clean_invoice.info()
clean_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 1 to 59
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   first_name      59 non-null     object
#  1   last_name       59 non-null     object
#  2   company         59 non-null     object
#  3   address         59 non-null     object
#  4   city            59 non-null     object
#  5   state           59 non-null     object
#  6   country         59 non-null     object
#  7   postal_code     59 non-null     object
#  8   phone           59 non-null     object
#  9   fax             59 non-null     object
#  10  email           59 non-null     object
#  11  support_rep_id  59 non-null     int64
# dtypes: int64(1), object(11)
# memory usage: 6.0+ KB

# %%
# print(clean_invoice.isna().sum())
print(clean_customer.isna().sum())
# Out:
# first_name        0
# last_name         0
# company           0
# address           0
# city              0
# state             0
# country           0
# postal_code       0
# phone             0
# fax               0
# email             0
# support_rep_id    0
# dtype: int64

# %%
clean_customer.head()
# Out:
#             first_name    last_name  \
# customer_id
# 1                 Luís    Gonçalves
# 2               Leonie       Köhler
# 3             François     Tremblay
# 4                Bjørn       Hansen
# 5            František  Wichterlová
#
#                                                       company  \
# customer_id
# 1            Embraer - Empresa Brasileira de Aeronáutica S.A.
# 2                                                     Unknown
# 3                                                     Unknown
# 4                                                     Unknown
# 5                                            JetBrains s.r.o.
#
#                                      address                 city    state  \
# customer_id
# 1            Av. Brigadeiro Faria Lima, 2170  São José dos Campos       SP
# 2                    Theodor-Heuss-Straße 34            Stuttgart  Unknown
# 3                          1498 rue Bélanger             Montréal       QC
# ...

# %%
# clean employee dataset
clean_employee=pd.read_csv('/content/drive/MyDrive/sample_data/clean-employee.csv',index_col='employee_id');
clean_employee.head()
# Out:
#             last_name first_name                title  reports_to  \
# employee_id
# 1               Adams     Andrew      General Manager         0.0
# 2             Edwards      Nancy        Sales Manager         1.0
# 3             Peacock       Jane  Sales Support Agent         2.0
# 4                Park   Margaret  Sales Support Agent         2.0
# 5             Johnson      Steve  Sales Support Agent         2.0
#
#                       birth_date            hire_date              address  \
# employee_id
# 1            1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW
# 2            1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW
# 3            1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW
# 4            1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW
# 5            1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave
#
#                  city state country postal_code              phone  \
# employee_id
# ...

# %%
clean_employee.to_csv('/content/drive/MyDrive/sample_data/clean-employee.csv')

# %%
# clean_employee.fillna(0, inplace=True)
clean_employee.head()
# Out:
#             last_name first_name                title  reports_to  \
# employee_id
# 1               Adams     Andrew      General Manager         0.0
# 2             Edwards      Nancy        Sales Manager         1.0
# 3             Peacock       Jane  Sales Support Agent         2.0
# 4                Park   Margaret  Sales Support Agent         2.0
# 5             Johnson      Steve  Sales Support Agent         2.0
#
#                       birth_date            hire_date              address  \
# employee_id
# 1            1962-02-18 00:00:00  2002-08-14 00:00:00  11120 Jasper Ave NW
# 2            1958-12-08 00:00:00  2002-05-01 00:00:00         825 8 Ave SW
# 3            1973-08-29 00:00:00  2002-04-01 00:00:00        1111 6 Ave SW
# 4            1947-09-19 00:00:00  2003-05-03 00:00:00     683 10 Street SW
# 5            1965-03-03 00:00:00  2003-10-17 00:00:00         7727B 41 Ave
#
#                  city state country postal_code              phone  \
# employee_id
# ...

# %%
print(clean_employee.isna().sum())
# Out:
# last_name      0
# first_name     0
# title          0
# reports_to     0
# birth_date     0
# hire_date      0
# address        0
# city           0
# state          0
# country        0
# postal_code    0
# phone          0
# fax            0
# email          0
# dtype: int64

# %%
clean_employee.to_csv('sample_data/clean-employee.csv')

# %%
# Clean track dataset
clean_track=pd.read_csv('/content/drive/MyDrive/sample_data/clean-track.csv',index_col='track_id');
clean_track.head()
# Out:
#                                              name  album_id  media_type_id  \
# track_id
# 1         For Those About To Rock (We Salute You)         1              1
# 2                               Balls to the Wall         2              2
# 3                                 Fast As a Shark         3              2
# 4                               Restless and Wild         3              2
# 5                            Princess of the Dawn         3              2
#
#           genre_id                                           composer  \
# track_id
# 1                1          Angus Young, Malcolm Young, Brian Johnson
# 2                1  U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...
# 3                1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...
# 4                1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...
# 5                1                         Deaffy & R.A. Smith-Diesel
#
#           milliseconds     bytes  unit_price
# track_id
# ...

# %%
# clean_track['composer'].fillna('Unknown', inplace=True)
clean_track.head()
# Out:
#                                              name  album_id  media_type_id  \
# track_id
# 1         For Those About To Rock (We Salute You)         1              1
# 2                               Balls to the Wall         2              2
# 3                                 Fast As a Shark         3              2
# 4                               Restless and Wild         3              2
# 5                            Princess of the Dawn         3              2
#
#           genre_id                                           composer  \
# track_id
# 1                1          Angus Young, Malcolm Young, Brian Johnson
# 2                1  U. Dirkschneider, W. Hoffmann, H. Frank, P. Ba...
# 3                1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...
# 4                1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...
# 5                1                         Deaffy & R.A. Smith-Diesel
#
#           milliseconds     bytes  unit_price
# track_id
# ...

# %%
clean_track.isna().sum()
# Out:
# name             0
# album_id         0
# media_type_id    0
# genre_id         0
# composer         0
# milliseconds     0
# bytes            0
# unit_price       0
# dtype: int64

# %%
clean_track.to_csv('/content/drive/MyDrive/sample_data/clean-track.csv')

# %%
invoiceLine=pd.read_csv('/content/drive/MyDrive/sample_data/invoice_line.csv',index_col='invoice_line_id');
invoiceLine.head()
# Out:
#                  invoice_id  track_id  unit_price  quantity
# invoice_line_id
# 1                         1         2        0.99         1
# 2                         1         4        0.99         1
# 3                         2         6        0.99         1
# 4                         2         8        0.99         1
# 5                         2        10        0.99         1

# %%
invoiceLine.isna().sum()
# Out:
# invoice_id    0
# track_id      0
# unit_price    0
# quantity      0
# dtype: int64

# %%
invoiceLine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2240 entries, 1 to 2240
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   invoice_id  2240 non-null   int64
#  1   track_id    2240 non-null   int64
#  2   unit_price  2240 non-null   float64
#  3   quantity    2240 non-null   int64
# dtypes: float64(1), int64(3)
# memory usage: 87.5 KB

# %%
album=pd.read_csv('/content/drive/MyDrive/sample_data/album.csv',index_col='album_id');
album.head()
# Out:
#                                           title  artist_id
# album_id
# 1         For Those About To Rock We Salute You          1
# 2                             Balls to the Wall          2
# 3                             Restless and Wild          2
# 4                             Let There Be Rock          1
# 5                                      Big Ones          3

# %%
album.isna().sum()
# Out:
# title        0
# artist_id    0
# dtype: int64

# %%
album.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 347 entries, 1 to 347
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      347 non-null    object
#  1   artist_id  347 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 8.1+ KB

# %%
artist=pd.read_csv('/content/drive/MyDrive/sample_data/artist.csv',index_col='artist_id');
artist.head()
# Out:
#                         name
# artist_id
# 1                      AC/DC
# 2                     Accept
# 3                  Aerosmith
# 4          Alanis Morissette
# 5            Alice In Chains

# %%
artist.isna().sum()
# Out:
# name    0
# dtype: int64

# %%
artist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 275 entries, 1 to 275
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    275 non-null    object
# dtypes: object(1)
# memory usage: 4.3+ KB

# %%
genre =pd.read_csv('/content/drive/MyDrive/sample_data/genre.csv',index_col='genre_id');
genre.head()
# Out:
#                         name
# genre_id
# 1                       Rock
# 2                       Jazz
# 3                      Metal
# 4         Alternative & Punk
# 5              Rock And Roll

# %%
genre.isna().sum()
# Out:
# name    0
# dtype: int64

# %%
genre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 1 to 25
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    25 non-null     object
# dtypes: object(1)
# memory usage: 400.0+ bytes

# %%
media_type=pd.read_csv('/content/drive/MyDrive/sample_data/media_type.csv',index_col='media_type_id');
media_type.head()
# Out:
#                                       name
# media_type_id
# 1                          MPEG audio file
# 2                 Protected AAC audio file
# 3              Protected MPEG-4 video file
# 4                 Purchased AAC audio file
# 5                           AAC audio file

# %%
media_type.isna().sum()
# Out:
# name    0
# dtype: int64

# %%
media_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 1 to 5
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
# dtypes: object(1)
# memory usage: 80.0+ bytes

# %%
playlist_track=pd.read_csv('/content/drive/MyDrive/sample_data/playlist_track.csv',index_col='playlist_id');
playlist_track.head()
# Out:
#              track_id
# playlist_id
# 1                3402
# 1                3389
# 1                3390
# 1                3391
# 1                3392

# %%
playlist_track.isna().sum()
# Out:
# track_id    0
# dtype: int64

# %%
playlist_track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8715 entries, 1 to 18
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   track_id  8715 non-null   int64
# dtypes: int64(1)
# memory usage: 136.2 KB

# %%
playlist =pd.read_csv('/content/drive/MyDrive/sample_data/playlist.csv',index_col='playlist_id');
playlist.head()
# Out:
#                    name
# playlist_id
# 1                 Music
# 2                Movies
# 3              TV Shows
# 4            Audiobooks
# 5            90’s Music

# %%
playlist.isna().sum()
# Out:
# name    0
# dtype: int64

# %%
playlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 1 to 18
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    18 non-null     object
# dtypes: object(1)
# memory usage: 288.0+ bytes
